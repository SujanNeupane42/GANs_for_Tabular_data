# %% [markdown]
# # Some preprocessing to implement tanh in generator

# %%
import pandas as pd
# normalized_df=(df-df.mean())/df.std()
df = pd.read_csv('train.csv')
df["label"] = df.Survived
df = df.drop(["PassengerId", "Survived", "Name", "Ticket", "Cabin"], axis=1)
# handling missing values
median_age = df.Age.median()
mode_embarked = df.Embarked.mode()[0]
df = df.fillna({"Age": median_age, "Embarked": mode_embarked})
df.Sex = df.Sex.replace({'male':0,'female':1})
df.Embarked = df.Embarked.replace({'S':0,'C':1,'Q':2})

# %% [markdown]
# # Importing the dependencies

# %%
import torch
from torch import nn
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import seaborn as sns

# %% [markdown]
# # Creating pytorch dataset and dataloader

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class MyDataset(Dataset):
 
  def __init__(self):
    df = pd.read_csv('train.csv')
    df["label"] = df.Survived
#     df = df[df['label'] == 1].reset_index(drop = True)
    df = df.drop(["PassengerId", "Survived", "Name", "Ticket", "Cabin"], axis=1)
    median_age = df.Age.median()
    mode_embarked = df.Embarked.mode()[0]
    df = df.fillna({"Age": median_age, "Embarked": mode_embarked})
    df.Sex = df.Sex.replace({'male':0,'female':1})
    df.Embarked = df.Embarked.replace({'S':0,'C':1,'Q':2})
 
    x = df.iloc[:, 0:7].values
    y = df.iloc[:, -1].values
 
    self.x_train=torch.tensor(x,dtype=torch.float32)
    self.y_train=torch.tensor(y,dtype=torch.int)
 
  def __len__(self):
    return len(self.y_train)
   
  def __getitem__(self,idx):
    return self.x_train[idx],self.y_train[idx]

train_ds = MyDataset()

# %%
batch_size = 64


train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=0, pin_memory=True)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %%
train_dl.device
# Out:
# device(type='cuda')

# %% [markdown]
# # Creating generator and discriminator models

# %% [markdown]
# <b> Generator Architecture

# %%
latent_size = 7
n_features = 7
num_classes = 2
embed_size = 2

# %%
class Generator(nn.Module):
    def __init__(self, embed_size = 2):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(n_features + embed_size, 16),
            nn.ReLU(),
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, 7),
#             nn.Linear(latent_size, 1024),
#             nn.ReLU(),
#             nn.Linear(1024, 512),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(512, 256),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(256, 128),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(128, 64),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(64, 32),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(32, 16),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(16, 7),
        )
        self.embed = nn.Embedding(num_classes, embed_size)

    def forward(self, x, labels):
        embed = self.embed(labels)#.reshape(labels.shape[0], 1)
        x = torch.cat([x, embed], dim = 1)
        output = self.model(x)
        return output
    

generator = to_device(Generator(), device)

# %% [markdown]
# <b> Discriminator Architecture

# %%
class Discriminator(nn.Module):
    def __init__(self, embed_size = 2):
        super().__init__()
        
        self.model = nn.Sequential(
            nn.Linear(n_features + embed_size, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, 1),
            nn.Sigmoid(),
#             nn.Linear(n_features, 1024),
#             nn.ReLU(),
#             nn.Linear(1024, 512),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(512, 256),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(256, 128),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(128, 64),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(64, 32),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(32, 16),
#             nn.ReLU(inplace = True),
#             nn.Dropout2d(0.2),
            
#             nn.Linear(16, 1),
#             nn.Sigmoid()
        )
        
        self.embed = nn.Embedding(num_classes, embed_size)

    def forward(self, x, labels):
        embed = self.embed(labels)#.reshape(labels.shape[0], 1)
        x = torch.cat([x, embed], dim = 1)
        output = self.model(x)
        return output
    
discriminator = to_device(Discriminator(), device)

# %%
# for arr, labels in train_dl:
#     break
# # nn.Embedding(2, 2).to('cuda')(labels)#.reshape(labels.shape[0], 1)

# %% [markdown]
# # Generator and discriminator training methodology

# %%
CRITIC_ITERATIONS = 5
# WEIGHT_CLIP = 0.01
LAMBDA_GP = 10

# %%
def gradient_penalty(real_data, generated_data, real_labels,device = device):
    BATCH_SIZE, features_count = real_data.shape
    epsilon = torch.rand((BATCH_SIZE, features_count)).to(device)
    epsilon = epsilon.to(device)

    interpolated_data = real_data * epsilon + generated_data * (1 - epsilon)


    # lets calculate critics score
    mixed_scores = discriminator(interpolated_data, real_labels)

    # Computes and returns the sum of gradients of outputs with respect to the inputs.
    # https://pytorch.org/docs/stable/generated/torch.ones_like.html
    # l2 norm : https://www.analyticsvidhya.com/blog/2021/03/must-known-vector-norms-in-machine-learning/
    gradient = torch.autograd.grad(
      inputs = interpolated_data,
      outputs = mixed_scores,
      grad_outputs = torch.ones_like(mixed_scores)
    )[0]

    gradient = gradient.view(gradient.shape[0], -1)
    gradient_norm = gradient.norm(2, dim = 1)
    gradient_penalty = torch.mean((gradient_norm - 1) ** 2)
    return gradient_penalty

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(real_data, opt_d, cur_batch_size, real_labels):
    # Reset gradients
    opt_d.zero_grad()
    
    real_labels = real_labels.to(device)
    real_preds = discriminator(real_data, real_labels).reshape(-1)

    # random noise from uniform distribution
    latent_space_samples = torch.randn((cur_batch_size, latent_size),  device = device)
    
    generated_data = generator(latent_space_samples, real_labels)  # fake data generated by generator
    fake_preds = discriminator(generated_data, real_labels).reshape(-1)
    
    # calculating gradient penalty
    gp = gradient_penalty(real_data, generated_data, real_labels,device = device)
    
    loss = -(torch.mean(real_preds) - torch.mean(fake_preds)) + LAMBDA_GP * gp

    # Compute gradients
    loss.backward()
    # Adjust the parameters using backprop
    opt_d.step()
        
    return loss

# %%
def train_generator(opt_g, cur_batch_size, real_labels):
    # Clear generator gradients
    opt_g.zero_grad()
     
    # random noise from uniform distribution
    latent_space_samples = torch.randn((cur_batch_size, latent_size),  device = device)
    generated_data = generator(latent_space_samples, real_labels)  # fake data generated by generator
    fake_preds = discriminator(generated_data, real_labels.to(device)).reshape(-1)
    g_loss = -torch.mean(fake_preds)

    g_loss.backward()
    opt_g.step()
    return g_loss

# %% [markdown]
# # Training Loop

# %%
lr = 0.001
epochs = 1000

# %%
opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas = (0.5, 0.9))
opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas = (0.5, 0.9))

# %%
def fit(epochs, lr, opt_d, opt_g):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []

    
    # Create optimizers
#     opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
#     opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    total_step = len(train_dl)
    for epoch in range(epochs):
        for i, (real_data, real_labels) in enumerate(train_dl):
            cur_batch_size = real_data.shape[0]
            
            for _ in range(CRITIC_ITERATIONS):            
                # Train the discriminator and generator
                d_loss = train_discriminator(real_data, opt_d, cur_batch_size, real_labels)            
                
            g_loss = train_generator(opt_g, cur_batch_size, real_labels)
            
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}'
                  .format(epoch, epochs, i+1, total_step, d_loss.item(), g_loss.item()))
        # Loss of last batch
        losses_d.append(d_loss.item())
        losses_g.append(g_loss.item())
    return losses_g, losses_d

# %%
# %%time

history = fit(epochs, lr, opt_d, opt_g)
# Out:
# Epoch [0/1000], Step [1/14], d_loss: 9.3413, g_loss: -0.5240
# Epoch [0/1000], Step [2/14], d_loss: 9.2487, g_loss: -0.4479
# Epoch [0/1000], Step [3/14], d_loss: 9.0772, g_loss: -0.3282
# Epoch [0/1000], Step [4/14], d_loss: 8.5880, g_loss: -0.1738
# Epoch [0/1000], Step [5/14], d_loss: 8.4588, g_loss: -0.0671
# Epoch [0/1000], Step [6/14], d_loss: 8.1519, g_loss: -0.0338
# Epoch [0/1000], Step [7/14], d_loss: 8.6120, g_loss: -0.0158
# Epoch [0/1000], Step [8/14], d_loss: 8.5281, g_loss: -0.0076
# Epoch [0/1000], Step [9/14], d_loss: 8.2686, g_loss: -0.0045
# Epoch [0/1000], Step [10/14], d_loss: 8.5019, g_loss: -0.0038
# Epoch [0/1000], Step [11/14], d_loss: 8.4825, g_loss: -0.0014
# Epoch [0/1000], Step [12/14], d_loss: 8.2872, g_loss: -0.0016
# Epoch [0/1000], Step [13/14], d_loss: 8.3794, g_loss: -0.0009
# Epoch [0/1000], Step [14/14], d_loss: 8.5520, g_loss: -0.0007
# Epoch [1/1000], Step [1/14], d_loss: 8.4974, g_loss: -0.0004
# Epoch [1/1000], Step [2/14], d_loss: 8.3731, g_loss: -0.0003
# Epoch [1/1000], Step [3/14], d_loss: 8.3960, g_loss: -0.0002
# Epoch [1/1000], Step [4/14], d_loss: 8.4312, g_loss: -0.0002
# Epoch [1/1000], Step [5/14], d_loss: 8.3319, g_loss: -0.0002
# Epoch [1/1000], Step [6/14], d_loss: 8.7775, g_loss: -0.0001
# Epoch [1/1000], Step [7/14], d_loss: 8.4732, g_loss: -0.0001
# Epoch [1/1000], Step [8/14], d_loss: 8.5942, g_loss: -0.0001
# Epoch [1/1000], Step [9/14], d_loss: 8.5246, g_loss: -0.0001
# Epoch [1/1000], Step [10/14], d_loss: 8.6880, g_loss: -0.0000
# Epoch [1/1000], Step [11/14], d_loss: 8.6225, g_loss: -0.0000
# Epoch [1/1000], Step [12/14], d_loss: 8.7131, g_loss: -0.0000
# Epoch [1/1000], Step [13/14], d_loss: 8.4785, g_loss: -0.0000
# Epoch [1/1000], Step [14/14], d_loss: 8.9884, g_loss: -0.0000
# Epoch [2/1000], Step [1/14], d_loss: 8.8301, g_loss: -0.0000
# Epoch [2/1000], Step [2/14], d_loss: 8.8724, g_loss: -0.0000
# Epoch [2/1000], Step [3/14], d_loss: 8.7678, g_loss: -0.0000
# Epoch [2/1000], Step [4/14], d_loss: 8.5230, g_loss: -0.0000
# Epoch [2/1000], Step [5/14], d_loss: 8.8622, g_loss: -0.0000
# Epoch [2/1000], Step [6/14], d_loss: 8.7397, g_loss: -0.0000
# Epoch [2/1000], Step [7/14], d_loss: 8.2561, g_loss: -0.0000
# Epoch [2/1000], Step [8/14], d_loss: 8.6500, g_loss: -0.0000
# Epoch [2/1000], Step [9/14], d_loss: 8.8431, g_loss: -0.0000
# Epoch [2/1000], Step [10/14], d_loss: 8.3152, g_loss: -0.0000
# Epoch [2/1000], Step [11/14], d_loss: 8.7094, g_loss: -0.0000
# Epoch [2/1000], Step [12/14], d_loss: 8.5498, g_loss: -0.0000
# Epoch [2/1000], Step [13/14], d_loss: 8.8816, g_loss: -0.0000
# Epoch [2/1000], Step [14/14], d_loss: 8.5862, g_loss: -0.0000
# Epoch [3/1000], Step [1/14], d_loss: 8.3852, g_loss: -0.0000
# Epoch [3/1000], Step [2/14], d_loss: 9.0894, g_loss: -0.0000
# Epoch [3/1000], Step [3/14], d_loss: 8.7398, g_loss: -0.0000
# Epoch [3/1000], Step [4/14], d_loss: 8.9255, g_loss: -0.0000
# Epoch [3/1000], Step [5/14], d_loss: 8.8826, g_loss: -0.0000
# Epoch [3/1000], Step [6/14], d_loss: 8.9987, g_loss: -0.0000
# Epoch [3/1000], Step [7/14], d_loss: 8.7155, g_loss: -0.0000
# Epoch [3/1000], Step [8/14], d_loss: 8.8434, g_loss: -0.0000
# Epoch [3/1000], Step [9/14], d_loss: 8.9965, g_loss: -0.0000
# Epoch [3/1000], Step [10/14], d_loss: 8.6889, g_loss: -0.0000
# Epoch [3/1000], Step [11/14], d_loss: 8.9601, g_loss: -0.0000
# Epoch [3/1000], Step [12/14], d_loss: 8.8504, g_loss: -0.0000
# Epoch [3/1000], Step [13/14], d_loss: 8.7501, g_loss: -0.0000
# Epoch [3/1000], Step [14/14], d_loss: 9.3014, g_loss: -0.0000
# Epoch [4/1000], Step [1/14], d_loss: 9.6680, g_loss: -0.0000
# Epoch [4/1000], Step [2/14], d_loss: 8.7471, g_loss: -0.0000
# Epoch [4/1000], Step [3/14], d_loss: 8.8262, g_loss: -0.0000
# Epoch [4/1000], Step [4/14], d_loss: 8.9479, g_loss: -0.0000
# Epoch [4/1000], Step [5/14], d_loss: 9.1138, g_loss: -0.0000
# Epoch [4/1000], Step [6/14], d_loss: 8.8590, g_loss: -0.0000
# Epoch [4/1000], Step [7/14], d_loss: 8.6922, g_loss: -0.0000
# Epoch [4/1000], Step [8/14], d_loss: 9.1841, g_loss: -0.0000
# Epoch [4/1000], Step [9/14], d_loss: 9.6623, g_loss: -0.0000
# Epoch [4/1000], Step [10/14], d_loss: 8.5291, g_loss: -0.0000
# Epoch [4/1000], Step [11/14], d_loss: 8.8419, g_loss: -0.0000
# Epoch [4/1000], Step [12/14], d_loss: 9.5432, g_loss: -0.0000
# Epoch [4/1000], Step [13/14], d_loss: 8.8573, g_loss: -0.0000
# Epoch [4/1000], Step [14/14], d_loss: 8.7298, g_loss: -0.0000
# Epoch [5/1000], Step [1/14], d_loss: 8.9914, g_loss: -0.0000
# Epoch [5/1000], Step [2/14], d_loss: 8.8568, g_loss: -0.0000
# Epoch [5/1000], Step [3/14], d_loss: 8.9953, g_loss: -0.0000
# Epoch [5/1000], Step [4/14], d_loss: 8.6473, g_loss: -0.0000
# Epoch [5/1000], Step [5/14], d_loss: 9.0842, g_loss: -0.0000
# Epoch [5/1000], Step [6/14], d_loss: 8.9023, g_loss: -0.0000
# Epoch [5/1000], Step [7/14], d_loss: 8.8857, g_loss: -0.0000
# Epoch [5/1000], Step [8/14], d_loss: 8.9989, g_loss: -0.0000
# Epoch [5/1000], Step [9/14], d_loss: 8.8730, g_loss: -0.0000
# Epoch [5/1000], Step [10/14], d_loss: 8.9957, g_loss: -0.0000
# Epoch [5/1000], Step [11/14], d_loss: 8.7228, g_loss: -0.0000
# Epoch [5/1000], Step [12/14], d_loss: 8.9524, g_loss: -0.0000
# Epoch [5/1000], Step [13/14], d_loss: 8.7869, g_loss: -0.0000
# Epoch [5/1000], Step [14/14], d_loss: 8.9997, g_loss: -0.0000
# Epoch
14], d_loss: 8.9997, g_loss: -0.0000
# Epoch [8/1000], Step [9/14], d_loss: 9.1884, g_loss: -0.0000
# Epoch [8/1000], Step [10/14], d_loss: 8.7425, g_loss: -0.0000
# Epoch [8/1000], Step [11/14], d_loss: 10.1173, g_loss: -0.0000
# Epoch [8/1000], Step [12/14], d_loss: 9.2744, g_loss: -0.0000
# Epoch [8/1000], Step [13/14], d_loss: 8.9303, g_loss: -0.0000
# Epoch [8/1000], Step [14/14], d_loss: 8.7399, g_loss: -0.0000
# Epoch [9/1000], Step [1/14], d_loss: 8.8713, g_loss: -0.0000
# Epoch [9/1000], Step [2/14], d_loss: 8.8536, g_loss: -0.0000
# Epoch [9/1000], Step [3/14], d_loss: 8.8839, g_loss: -0.0000
# Epoch [9/1000], Step [4/14], d_loss: 8.9801, g_loss: -0.0000
# Epoch [9/1000], Step [5/14], d_loss: 8.9769, g_loss: -0.0000
# Epoch [9/1000], Step [6/14], d_loss: 8.9854, g_loss: -0.0000
# Epoch [9/1000], Step [7/14], d_loss: 8.9302, g_loss: -0.0000
# Epoch [9/1000], Step [8/14], d_loss: 9.3294, g_loss: -0.0000
# Epoch [9/1000], Step [9/14], d_loss: 10.0723, g_loss: -0.0000
# Epoch [9/1000], Step [10/14], d_loss: 8.9518, g_loss: -0.0000
# Epoch [9/1000], Step [11/14], d_loss: 8.8352, g_loss: -0.0000
# Epoch [9/1000], Step [12/14], d_loss: 9.0395, g_loss: -0.0000
# Epoch [9/1000], Step [13/14], d_loss: 8.7320, g_loss: -0.0000
# Epoch [9/1000], Step [14/14], d_loss: 8.9902, g_loss: -0.0000
# Epoch [10/1000], Step [1/14], d_loss: 9.2805, g_loss: -0.0000
# Epoch [10/1000], Step [2/14], d_loss: 8.9080, g_loss: -0.0000
# Epoch [10/1000], Step [3/14], d_loss: 8.8127, g_loss: -0.0000
# Epoch [10/1000], Step [4/14], d_loss: 8.8507, g_loss: -0.0000
# Epoch [10/1000], Step [5/14], d_loss: 8.8386, g_loss: -0.0000
# Epoch [10/1000], Step [6/14], d_loss: 9.5493, g_loss: -0.0000
# Epoch [10/1000], Step [7/14], d_loss: 9.0104, g_loss: -0.0000
# Epoch [10/1000], Step [8/14], d_loss: 8.9838, g_loss: -0.0000
# Epoch [10/1000], Step [9/14], d_loss: 8.7483, g_loss: -0.0000
# Epoch [10/1000], Step [10/14], d_loss: 8.8965, g_loss: -0.0000
# Epoch [10/1000], Step [11/14], d_loss: 8.8343, g_loss: -0.0000
# Epoch [10/1000], Step [12/14], d_loss: 8.8904, g_loss: -0.0000
# Epoch [10/1000], Step [13/14], d_loss: 9.2892, g_loss: -0.0000
# Epoch [10/1000], Step [14/14], d_loss: 8.9957, g_loss: -0.0000
# Epoch [11/1000], Step [1/14], d_loss: 8.9450, g_loss: -0.0000
# Epoch [11/1000], Step [2/14], d_loss: 8.8361, g_loss: -0.0000
# Epoch [11/1000], Step [3/14], d_loss: 8.9556, g_loss: -0.0000
# Epoch [11/1000], Step [4/14], d_loss: 8.8309, g_loss: -0.0000
# Epoch [11/1000], Step [5/14], d_loss: 8.9247, g_loss: -0.0000
# Epoch [11/1000], Step [6/14], d_loss: 8.6173, g_loss: -0.0000
# Epoch [11/1000], Step [7/14], d_loss: 9.2764, g_loss: -0.0000
# Epoch [11/1000], Step [8/14], d_loss: 8.8204, g_loss: -0.0000
# Epoch [11/1000], Step [9/14], d_loss: 8.9443, g_loss: -0.0000
# Epoch [11/1000], Step [10/14], d_loss: 8.8967, g_loss: -0.0000
# Epoch [11/1000], Step [11/14], d_loss: 8.9603, g_loss: -0.0000
# Epoch [11/1000], Step [12/14], d_loss: 9.4907, g_loss: -0.0000
# Epoch [11/1000], Step [13/14], d_loss: 8.8349, g_loss: -0.0000
# Epoch [11/1000], Step [14/14], d_loss: 8.9806, g_loss: -0.0000
# Epoch [12/1000], Step [1/14], d_loss: 8.7745, g_loss: -0.0000
# Epoch [12/1000], Step [2/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [12/1000], Step [3/14], d_loss: 8.8720, g_loss: -0.0000
# Epoch [12/1000], Step [4/14], d_loss: 8.9021, g_loss: -0.0000
# Epoch [12/1000], Step [5/14], d_loss: 8.9371, g_loss: -0.0000
# Epoch [12/1000], Step [6/14], d_loss: 8.8740, g_loss: -0.0000
# Epoch [12/1000], Step [7/14], d_loss: 9.6906, g_loss: -0.0000
# Epoch [12/1000], Step [8/14], d_loss: 8.9147, g_loss: -0.0000
# Epoch [12/1000], Step [9/14], d_loss: 9.9266, g_loss: -0.0000
# Epoch [12/1000], Step [10/14], d_loss: 9.6776, g_loss: -0.0000
# Epoch [12/1000], Step [11/14], d_loss: 8.9914, g_loss: -0.0000
# Epoch [12/1000], Step [12/14], d_loss: 8.8005, g_loss: -0.0000
# Epoch [12/1000], Step [13/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [12/1000], Step [14/14], d_loss: 8.8411, g_loss: -0.0000
# Epoch [13/1000], Step [1/14], d_loss: 10.0553, g_loss: -0.0000
# Epoch [13/1000], Step [2/14], d_loss: 9.9910, g_loss: -0.0000
# Epoch [13/1000], Step [3/14], d_loss: 8.9622, g_loss: -0.0000
# Epoch [13/1000], Step [4/14], d_loss: 8.9960, g_loss: -0.0000
# Epoch [13/1000], Step [5/14], d_loss: 9.7626, g_loss: -0.0000
# Epoch [13/1000], Step [6/14], d_loss: 8.7196, g_loss: -0.0000
# Epoch [13/1000], Step [7/14], d_loss: 8.8158, g_loss: -0.0000
# Epoch [13/1000], Step [8/14], d_loss: 8.9083, g_loss: -0.0000
# Epoch [13/1000], Step [9/14], d_loss: 9.2391, g_loss: -0.0000
# Epoch [13/1000], Step [10/14], d_loss: 8.9805, g_loss: -0.0000
# Epoch [13/1000], Step [11/14], d_loss: 9.4256, g_loss: -0.0000
# Epoch [13/1000], Step [12/14], d_loss: 8.9593, g_loss: -0.0000
# Epoch [13/1000], Step [13/14], d_loss: 10.0907, g_loss: -0.0000
# Epoch [13/1000], Step [14/14], d_loss: 8.9578, g_loss: -0.0000
# Epoch [14/1000], Step [1/14], d_loss: 8.9985, g_loss: -0.0000
# Epoch [14/1000], Step [2/14], d_loss: 8.9998, g_loss: -0.0000
# Epoch [14/1000], Step [3/14], d_loss: 8.9981, g_loss: -0.0000
# Epoch [14/1000], Step [4/14], d_loss: 8.9997, g_loss: -0.0000
# Epoch
# Epoch [23/1000], Step [4/14], d_loss: 8.9558, g_loss: -0.0000
# Epoch [23/1000], Step [5/14], d_loss: 9.7433, g_loss: -0.0000
# Epoch [23/1000], Step [6/14], d_loss: 8.9718, g_loss: -0.0000
# Epoch [23/1000], Step [7/14], d_loss: 8.9458, g_loss: -0.0000
# Epoch [23/1000], Step [8/14], d_loss: 8.6138, g_loss: -0.0000
# Epoch [23/1000], Step [9/14], d_loss: 8.9251, g_loss: -0.0000
# Epoch [23/1000], Step [10/14], d_loss: 9.0052, g_loss: -0.0000
# Epoch [23/1000], Step [11/14], d_loss: 9.1385, g_loss: -0.0000
# Epoch [23/1000], Step [12/14], d_loss: 10.0387, g_loss: -0.0000
# Epoch [23/1000], Step [13/14], d_loss: 8.9327, g_loss: -0.0000
# Epoch [23/1000], Step [14/14], d_loss: 9.5801, g_loss: -0.0000
# Epoch [24/1000], Step [1/14], d_loss: 9.8629, g_loss: -0.0000
# Epoch [24/1000], Step [2/14], d_loss: 8.9994, g_loss: -0.0000
# Epoch [24/1000], Step [3/14], d_loss: 8.9922, g_loss: -0.0000
# Epoch [24/1000], Step [4/14], d_loss: 9.5833, g_loss: -0.0000
# Epoch [24/1000], Step [5/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [24/1000], Step [6/14], d_loss: 9.6191, g_loss: -0.0000
# Epoch [24/1000], Step [7/14], d_loss: 8.9426, g_loss: -0.0000
# Epoch [24/1000], Step [8/14], d_loss: 9.1440, g_loss: -0.0000
# Epoch [24/1000], Step [9/14], d_loss: 8.8462, g_loss: -0.0000
# Epoch [24/1000], Step [10/14], d_loss: 8.6550, g_loss: -0.0000
# Epoch [24/1000], Step [11/14], d_loss: 8.9988, g_loss: -0.0000
# Epoch [24/1000], Step [12/14], d_loss: 8.8716, g_loss: -0.0000
# Epoch [24/1000], Step [13/14], d_loss: 8.9666, g_loss: -0.0000
# Epoch [24/1000], Step [14/14], d_loss: 8.9511, g_loss: -0.0000
# Epoch [25/1000], Step [1/14], d_loss: 8.8178, g_loss: -0.0000
# Epoch [25/1000], Step [2/14], d_loss: 8.8833, g_loss: -0.0000
# Epoch [25/1000], Step [3/14], d_loss: 8.7637, g_loss: -0.0000
# Epoch [25/1000], Step [4/14], d_loss: 8.7430, g_loss: -0.0000
# Epoch [25/1000], Step [5/14], d_loss: 8.8451, g_loss: -0.0000
# Epoch [25/1000], Step [6/14], d_loss: 8.9395, g_loss: -0.0000
# Epoch [25/1000], Step [7/14], d_loss: 9.9901, g_loss: -0.0000
# Epoch [25/1000], Step [8/14], d_loss: 8.7312, g_loss: -0.0000
# Epoch [25/1000], Step [9/14], d_loss: 8.9463, g_loss: -0.0000
# Epoch [25/1000], Step [10/14], d_loss: 8.5659, g_loss: -0.0000
# Epoch [25/1000], Step [11/14], d_loss: 8.9714, g_loss: -0.0000
# Epoch [25/1000], Step [12/14], d_loss: 9.7598, g_loss: -0.0000
# Epoch [25/1000], Step [13/14], d_loss: 8.9552, g_loss: -0.0000
# Epoch [25/1000], Step [14/14], d_loss: 8.7416, g_loss: -0.0000
# Epoch [26/1000], Step [1/14], d_loss: 8.7469, g_loss: -0.0000
14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [43/1000], Step [10/14], d_loss: 9.9104, g_loss: -0.0000
# Epoch [43/1000], Step [11/14], d_loss: 9.4053, g_loss: -0.0000
# Epoch [43/1000], Step [12/14], d_loss: 9.1775, g_loss: -0.0000
# Epoch [43/1000], Step [13/14], d_loss: 9.1984, g_loss: -0.0000
# Epoch [43/1000], Step [14/14], d_loss: 8.9943, g_loss: -0.0000
# Epoch [44/1000], Step [1/14], d_loss: 9.9497, g_loss: -0.0000
# Epoch [44/1000], Step [2/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [44/1000], Step [3/14], d_loss: 8.9785, g_loss: -0.0000
# Epoch [44/1000], Step [4/14], d_loss: 10.0831, g_loss: -0.0000
# Epoch [44/1000], Step [5/14], d_loss: 8.9230, g_loss: -0.0000
# Epoch [44/1000], Step [6/14], d_loss: 8.5072, g_loss: -0.0000
# Epoch [44/1000], Step [7/14], d_loss: 8.8984, g_loss: -0.0000
# Epoch [44/1000], Step [8/14], d_loss: 8.8180, g_loss: -0.0000
# Epoch [44/1000], Step [9/14], d_loss: 8.9971, g_loss: -0.0000
# Epoch [44/1000], Step [10/14], d_loss: 9.2546, g_loss: -0.0000
# Epoch [44/1000], Step [11/14], d_loss: 9.1513, g_loss: -0.0000
# Epoch [44/1000], Step [12/14], d_loss: 9.4787, g_loss: -0.0000
# Epoch [44/1000], Step [13/14], d_loss: 8.8961, g_loss: -0.0000
# Epoch [44/1000], Step [14/14], d_loss: 8.8945, g_loss: -0.0000
# Epoch [45/1000], Step [1/14], d_loss: 8.9937, g_loss: -0.0000
# Epoch [45/1000], Step [2/14], d_loss: 8.5759, g_loss: -0.0000
# Epoch [45/1000], Step [3/14], d_loss: 8.9181, g_loss: -0.0000
# Epoch [45/1000], Step [4/14], d_loss: 8.9981, g_loss: -0.0000
# Epoch [45/1000], Step [5/14], d_loss: 9.1803, g_loss: -0.0000
# Epoch [45/1000], Step [6/14], d_loss: 8.9652, g_loss: -0.0000
# Epoch [45/1000], Step [7/14], d_loss: 8.8529, g_loss: -0.0000
# Epoch [45/1000], Step [8/14], d_loss: 8.9994, g_loss: -0.0000
# Epoch [45/1000], Step [9/14], d_loss: 8.8060, g_loss: -0.0000
# Epoch [45/1000], Step [10/14], d_loss: 8.7205, g_loss: -0.0000
# Epoch [45/1000], Step [11/14], d_loss: 8.7708, g_loss: -0.0000
# Epoch [45/1000], Step [12/14], d_loss: 8.9912, g_loss: -0.0000
# Epoch [45/1000], Step [13/14], d_loss: 8.9664, g_loss: -0.0000
# Epoch [45/1000], Step [14/14], d_loss: 8.9937, g_loss: -0.0000
# Epoch [46/1000], Step [1/14], d_loss: 10.8327, g_loss: -0.0000
# Epoch [46/1000], Step [2/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [46/1000], Step [3/14], d_loss: 8.9846, g_loss: -0.0000
# Epoch [46/1000], Step [4/14], d_loss: 8.9168, g_loss: -0.0000
# Epoch [46/1000], Step [5/14], d_loss: 9.2833, g_loss: -0.0000
# Epoch [46/1000], Step [6/14], d_loss: 9.7526, g_loss: -0.0000
# Epoch [46/1000], Step [7/14], d_loss: 9.6760, g_loss: -0.0000
# Epoch [46/1000], Step [8/14], d_loss: 8.7707, g_loss: -0.0000
# Epoch [46/1000], Step [9/14], d_loss: 8.9999, g_loss: -0.0000
# Epoch [46/1000], Step [10/14], d_loss: 9.0278, g_loss: -0.0000
# Epoch [46/1000], Step [11/14], d_loss: 9.2739, g_loss: -0.0000
# Epoch [46/1000], Step [12/14], d_loss: 9.4355, g_loss: -0.0000
# Epoch [46/1000], Step [13/14], d_loss: 8.9997, g_loss: -0.0000
# Epoch [46/1000], Step [14/14], d_loss: 8.9321, g_loss: -0.0000
# Epoch [47/1000], Step [1/14], d_loss: 10.2860, g_loss: -0.0000
# Epoch [47/1000], Step [2/14], d_loss: 8.9770, g_loss: -0.0000
# Epoch [47/1000], Step [3/14], d_loss: 8.6228, g_loss: -0.0000
# Epoch [47/1000], Step [4/14], d_loss: 8.9965, g_loss: -0.0000
# Epoch [47/1000], Step [5/14], d_loss: 9.1008, g_loss: -0.0000
# Epoch [47/1000], Step [6/14], d_loss: 9.3480, g_loss: -0.0000
# Epoch [47/1000], Step [7/14], d_loss: 8.9222, g_loss: -0.0000
# Epoch [47/1000], Step [8/14], d_loss: 8.9999, g_loss: -0.0000
# Epoch [47/1000], Step [9/14], d_loss: 8.9994, g_loss: -0.0000
# Epoch [47/1000], Step [10/14], d_loss: 8.9929, g_loss: -0.0000
# Epoch [47/1000], Step [11/14], d_loss: 9.5804, g_loss: -0.0000
# Epoch [47/1000], Step [12/14], d_loss: 8.8581, g_loss: -0.0000
# Epoch [47/1000], Step [13/14], d_loss: 9.5284, g_loss: -0.0000
# Epoch [47/1000], Step [14/14], d_loss: 8.9089, g_loss: -0.0000
# Epoch [48/1000], Step [1/14], d_loss: 9.5984, g_loss: -0.0000
# Epoch [48/1000], Step [2/14], d_loss: 8.9833, g_loss: -0.0000
# Epoch [48/1000], Step [3/14], d_loss: 8.8717, g_loss: -0.0000
# Epoch [48/1000], Step [4/14], d_loss: 8.9988, g_loss: -0.0000
# Epoch [48/1000], Step [5/14], d_loss: 8.6074, g_loss: -0.0000
# Epoch [48/1000], Step [6/14], d_loss: 8.9932, g_loss: -0.0000
# Epoch [48/1000], Step [7/14], d_loss: 8.9922, g_loss: -0.0000
# Epoch [48/1000], Step [8/14], d_loss: 8.9423, g_loss: -0.0000
# Epoch [48/1000], Step [9/14], d_loss: 10.9268, g_loss: -0.0000
# Epoch [48/1000], Step [10/14], d_loss: 8.8573, g_loss: -0.0000
# Epoch [48/1000], Step [11/14], d_loss: 9.1995, g_loss: -0.0000
# Epoch [48/1000], Step [12/14], d_loss: 9.1937, g_loss: -0.0000
# Epoch [48/1000], Step [13/14], d_loss: 8.9474, g_loss: -0.0000
# Epoch [48/1000], Step [14/14], d_loss: 8.9670, g_loss: -0.0000
# Epoch [49/1000], Step [1/14], d_loss: 8.9749, g_loss: -0.0000
# Epoch [49/1000], Step [2/14], d_loss: 8.9995, g_loss: -0.0000
# Epoch [49/1000], Step [3/14], d_loss: 8.9627, g_loss: -0.0000
# Epoch [49/1000], Step [4/14], d_loss: 8.8463, g_loss: -0.0000
# Epoch [49/1000], Step [5/14], d_loss: 8.9999, g_loss: -0.0000
# Epoch [49/1000], Step [6/14], d_loss: 8.8814, g_loss: -0.0000
# Epoch [49/1000], Step [7/14], d_loss: 8.9475, g_loss: -0.0000
# Epoch [49/1000], Step [8/14], d_loss: 10.0345, g_loss: -0.0000
# Epoch [49/1000], Step [9/14], d_loss: 8.9985, g_loss: -0.0000
# Epoch [49/1000], Step [10/14], d_loss: 8.8038, g_loss: -0.0000
# Epoch [49/1000], Step [11/14], d_loss: 8.4999, g_loss: -0.0000
# Epoch [49/1000], Step [12/14], d_loss: 8.8024, g_loss: -0.0000
# Epoch [992/1000], Step [13/14], d_loss: 8.9987, g_loss: -0.0000
# Epoch [992/1000], Step [14/14], d_loss: 10.7197, g_loss: -0.0000
# Epoch [993/1000], Step [1/14], d_loss: 8.9988, g_loss: -0.0000
# Epoch [993/1000], Step [2/14], d_loss: 8.8936, g_loss: -0.0000
# Epoch [993/1000], Step [3/14], d_loss: 8.9997, g_loss: -0.0000
# Epoch [993/1000], Step [4/14], d_loss: 8.9458, g_loss: -0.0000
# Epoch [993/1000], Step [5/14], d_loss: 8.9922, g_loss: -0.0000
# Epoch [993/1000], Step [6/14], d_loss: 12.1504, g_loss: -0.0000
# Epoch [993/1000], Step [7/14], d_loss: 8.9217, g_loss: -0.0000
# Epoch [993/1000], Step [8/14], d_loss: 8.9548, g_loss: -0.0000
# Epoch [993/1000], Step [9/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [993/1000], Step [10/14], d_loss: 8.9985, g_loss: -0.0000
# Epoch [993/1000], Step [11/14], d_loss: 8.9764, g_loss: -0.0000
# Epoch [993/1000], Step [12/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [993/1000], Step [13/14], d_loss: 8.9999, g_loss: -0.0000
# Epoch [993/1000], Step [14/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [994/1000], Step [1/14], d_loss: 9.4660, g_loss: -0.0000
# Epoch [994/1000], Step [2/14], d_loss: 8.9998, g_loss: -0.0000
# Epoch [994/1000], Step [3/14], d_loss: 8.9998, g_loss: -0.0000
# Epoch [994/1000], Step [4/14], d_loss: 9.3606, g_loss: -0.0000
# Epoch [994/1000], Step [5/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [994/1000], Step [6/14], d_loss: 8.9952, g_loss: -0.0000
# Epoch [994/1000], Step [7/14], d_loss: 8.8018, g_loss: -0.0000
# Epoch [994/1000], Step [8/14], d_loss: 9.1223, g_loss: -0.0000
# Epoch [994/1000], Step [9/14], d_loss: 9.8162, g_loss: -0.0000
# Epoch [994/1000], Step [10/14], d_loss: 8.9998, g_loss: -0.0000
# Epoch [994/1000], Step [11/14], d_loss: 8.9208, g_loss: -0.0000
# Epoch [994/1000], Step [12/14], d_loss: 8.9117, g_loss: -0.0000
# Epoch [994/1000], Step [13/14], d_loss: 12.4359, g_loss: -0.0000
# Epoch [994/1000], Step [14/14], d_loss: 9.5344, g_loss: -0.0000
# Epoch [995/1000], Step [1/14], d_loss: 10.3126, g_loss: -0.0000
# Epoch [995/1000], Step [2/14], d_loss: 8.9411, g_loss: -0.0000
# Epoch [995/1000], Step [3/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [995/1000], Step [4/14], d_loss: 9.4332, g_loss: -0.0000
# Epoch [995/1000], Step [5/14], d_loss: 12.0574, g_loss: -0.0000
# Epoch [995/1000], Step [6/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [995/1000], Step [7/14], d_loss: 9.1993, g_loss: -0.0000
# Epoch [995/1000], Step [8/14], d_loss: 8.9898, g_loss: -0.0000
# Epoch [995/1000], Step [9/14], d_loss: 9.4638, g_loss: -0.0000
# Epoch [995/1000], Step [10/14], d_loss: 8.8630, g_loss: -0.0000
# Epoch [995/1000], Step [11/14], d_loss: 8.8755, g_loss: -0.0000
# Epoch [995/1000], Step [12/14], d_loss: 8.9372, g_loss: -0.0000
# Epoch [995/1000], Step [13/14], d_loss: 8.9982, g_loss: -0.0000
# Epoch [995/1000], Step [14/14], d_loss: 8.9496, g_loss: -0.0000
# Epoch [996/1000], Step [1/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [996/1000], Step [2/14], d_loss: 10.2332, g_loss: -0.0000
# Epoch [996/1000], Step [3/14], d_loss: 8.8285, g_loss: -0.0000
# Epoch [996/1000], Step [4/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch
14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [999/1000], Step [11/14], d_loss: 9.0000, g_loss: -0.0000
# Epoch [999/1000], Step [12/14], d_loss: 10.7311, g_loss: -0.0000
# Epoch [999/1000], Step [13/14], d_loss: 8.8658, g_loss: -0.0000
# Epoch [999/1000], Step [14/14], d_loss: 8.9638, g_loss: -0.0000
# Wall time: 9min 50s

# %%
losses_g, losses_d = history[0], history[1]

fig, axes = plt.subplots(1,1, figsize=(30, 12))
ax1 = plt.subplot(1,1,1)

plt.plot(range(1,1001), losses_g, label = 'Generator')
plt.plot(range(1, 1001), losses_d, label = 'Discriminator')
ax1.tick_params(labelsize = 30)
ax1.set_xlabel('Number of Iterations', fontsize = 40)
ax1.set_ylabel('Loss (Binary Cross Entropy)', fontsize = 40)
plt.title('Gen vs Dis loss across training', fontsize = 50)
plt.legend(fontsize = 40)

# %% [markdown]
# # Testing Generated Samples from Trained Generator

# %%
df.label.value_counts()
# Out:
# 0    549
# 1    342
# Name: label, dtype: int64

# %%
def generate_samples(number_of_samples_to_generate, class_val):
    if class_val == 0:
        label = torch.zeros(number_of_samples_to_generate, dtype=torch.int).to(device)
    elif class_val == 1:
        label = torch.ones(number_of_samples_to_generate, dtype=torch.int).to(device)
        
        
    latent_space_samples = torch.randn(number_of_samples_to_generate, n_features).to(device)
    generated_samples = generator(latent_space_samples, label)
#     print('generated_samples: ', generated_samples.shape)
#     print('label: ', label.shape)
    generated_samples = torch.concat([generated_samples, label.reshape(number_of_samples_to_generate, 1)], \
                                     dim = 1)
    generated_samples = generated_samples.cpu().detach().numpy()
    df_generated = pd.DataFrame(generated_samples, columns = df.columns)
    
    return df_generated

# %%
df_generated_0 = generate_samples(549, 0)
df_generated_1 = generate_samples(342, 1)

# %% [markdown]
# # Checking distributions of synthetic data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df0 = df[df.label == 0]
df1 = df[df.label == 1]

# %% [markdown]
# <b> For class 0

# %%
print('FOR CLASS 0')
fig, axes = plt.subplots(7, 1, figsize=(10, 50))

for n, col in enumerate(df.columns.to_list()[:-1]):
    ax1 = plt.subplot(7,1, n+1)
    sns.distplot(x = df_generated_0[col], color = 'red', label = 'Generated')
    sns.distplot(x = df0[col], color = 'blue', label = 'real')
    plt.legend(fontsize = 30)
    plt.xlabel(col, fontsize = 30)
    plt.title(col, fontsize = 30)
    plt.ylabel(' ')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
# Out:
# FOR CLASS 0

# %% [markdown]
# <b> For class 1

# %%
print('FOR CLASS 1')
fig, axes = plt.subplots(7, 1, figsize=(10, 50))

for n, col in enumerate(df.columns.to_list()[:-1]):
    ax1 = plt.subplot(7,1, n+1)
    sns.distplot(x = df_generated_1[col], color = 'red', label = 'Generated')
    sns.distplot(x = df1[col], color = 'blue', label = 'real')
    plt.legend(fontsize = 30)
    plt.xlabel(col, fontsize = 30)
    plt.title(col, fontsize = 30)
    plt.ylabel(' ')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
# Out:
# FOR CLASS 1
